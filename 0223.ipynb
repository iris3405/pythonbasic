# %%
#필요한 모듈 설치

# !pip install pillow    
# !pip install requests
# Out:
# Requirement already satisfied: pillow in c:\users\kych1\anaconda3\lib\site-packages (8.0.1)
# Requirement already satisfied: requests in c:\users\kych1\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kych1\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kych1\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kych1\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kych1\anaconda3\lib\site-packages (from requests) (2020.6.20)

# %%
import matplotlib.pyplot as plt   # 그림관련
import matplotlib.image as mpimg  # 사진관련


# %matplotlib inline

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 유명인 얼굴과 얼마나 비슷한지 검색

import requests  # 인터넷 연결

client_id = "c5V3FjXGq2uX5T5eNsp0"
client_secret = "qccuz1T3Fl"

url = "https://openapi.naver.com/v1/vision/celebrity"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json  #json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999797
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.870835
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941112
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.990651
#             }
#         },
#         {
#             "roi": {
#                 "x": 268,
#                 "y": 71,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999965
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.870391
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.996715
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.777422
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 144,
#                 "width": 26,
#                 "height": 26
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.882768
#             },
#             "age": {
#                 "value": "5~9",
#                 "confidence": 0.941211
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.989725
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.895872
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 153,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 138,
#                     "y": 159
#                 },
#                 "rightEye": {
#                     "x": 148,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 164
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 168
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.902951
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.0996041
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.897915
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.96725
#             }
#         }
#     ]
# }

# %%
# 얼굴인식,나이 예측, 감정 상태 분석

import requests  # 인터넷 연결

client_id = "c5V3FjXGq2uX5T5eNsp0"
client_secret = "qccuz1T3Fl"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json  #json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))

# 최대 2메가 제한
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999797
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.870835
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941112
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.990651
#             }
#         },
#         {
#             "roi": {
#                 "x": 268,
#                 "y": 71,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999965
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.870391
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.996715
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.777422
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 144,
#                 "width": 26,
#                 "height": 26
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.882768
#             },
#             "age": {
#                 "value": "5~9",
#                 "confidence": 0.941211
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.989725
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.895872
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 153,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 138,
#                     "y": 159
#                 },
#                 "rightEye": {
#                     "x": 148,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 164
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 168
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.902951
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.0996041
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.897915
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.96725
#             }
#         }
#     ]
# }

# %%
##기본문법학습

# %%
#dict형과 json에 대해

dict = {'name':'pinkwink','Age':'None','Class':['beginner','blog']}
dict
# Out:
# {'name': 'pinkwink', 'Age': 'None', 'Class': ['beginner', 'blog']}

# %%
dict.keys()
# Out:
# dict_keys(['name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict['Class']
# Out:
# ['beginner', 'blog']

# %%
dict.get('name')
# Out:
# 'pinkwink'

# %%
dict.get('Room','nothing')
# Out:
# 'nothing'

# %%
###json(java script object notation)

# %%
customer = { 
    'id':'0001',
    'name':'홍길동',
    'history':[
        {'date':'2019-03-01','log':True},
        {'date':'2019-03-02','log':False},
    ]
}

# %%
import json
json-test = json.dumps(customer, indent=4, ensure_ascil=False)
print(json_test)
# Out:
#   File "<ipython-input-46-684ef5d32664>", line 2
#     json-test = json.dumps(customer, indent=4, ensure_ascil=False)
#     ^
# SyntaxError: cannot assign to operator

# %%
##사진위에 개인 정보 표시하기

# %%
img = mpimg.imread('face1.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴인식,나이 예측, 감정 상태 분석

import requests  # 인터넷 연결

client_id = "c5V3FjXGq2uX5T5eNsp0"
client_secret = "qccuz1T3Fl"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face1.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json  #json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 293,
#             "height": 172
#         },
#         "faceCount": 1
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 117,
#                 "y": 41,
#                 "width": 46,
#                 "height": 46
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 128,
#                     "y": 53
#                 },
#                 "rightEye": {
#                     "x": 151,
#                     "y": 54
#                 },
#                 "nose": {
#                     "x": 138,
#                     "y": 68
#                 },
#                 "leftMouth": {
#                     "x": 129,
#                     "y": 78
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 80
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999986
#             },
#             "age": {
#                 "value": "31~35",
#                 "confidence": 0.758613
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 1.0
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998061
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces'][0]
# Out:
# {'roi': {'x': 117, 'y': 41, 'width': 46, 'height': 46},
#  'landmark': {'leftEye': {'x': 128, 'y': 53},
#   'rightEye': {'x': 151, 'y': 54},
#   'nose': {'x': 138, 'y': 68},
#   'leftMouth': {'x': 129, 'y': 78},
#   'rightMouth': {'x': 147, 'y': 80}},
#  'gender': {'value': 'male', 'confidence': 0.999986},
#  'age': {'value': '31~35', 'confidence': 0.758613},
#  'emotion': {'value': 'neutral', 'confidence': 1.0},
#  'pose': {'value': 'frontal_face', 'confidence': 0.998061}}

# %%
parsed['faces'][0]['roi'] #얼굴의 위치값
# Out:
# {'x': 117, 'y': 41, 'width': 46, 'height': 46}

# %%
parsed['faces'][0]['gender']
# Out:
# {'value': 'male', 'confidence': 0.999986}

# %%
parsed['faces'][0]['emotion']
# Out:
# {'value': 'neutral', 'confidence': 1.0}

# %%
x,y,w,h = parsed['faces'][0]['roi'].values()
gender,gen_confi = parsed['faces'][0]['gender'].values()
emotion,emo_confi = parsed['faces'][0]['emotion'].values()
age,age_confi = parsed['faces'][0]['age'].values()

# %%
annotation = gender + " : " + str(gen_confi) + '\n' + emotion + " : " + str(emo_confi) + '\n' + age + " ; " + str(age_confi)

# %%
print(annotation)
# Out:
# male : 0.999986
# neutral : 1.0
# 31~35 ; 0.758613

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')

ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap=True, fontsize = 17, color = 'white')
plt.show()

# %%
import matplotlib.patches as patches

img = mpimg.imread('face1.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

rect_face = patches.Rectangle((x,y),w,h,
                             linewidth = 5,
                             edgecolor = 'r',
                             facecolor = 'none')
ax.add_patch(rect_face)

plt.text(10,400, annotation, wrap=True, fontsize = 17, color ='black')
plt.show()

# %%
img = mpimg.imread('face2.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
# 얼굴인식,나이 예측, 감정 상태 분석

import requests  # 인터넷 연결

client_id = "c5V3FjXGq2uX5T5eNsp0"
client_secret = "qccuz1T3Fl"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('face2.jpg','rb')}
headers = {'X-Naver-Client-Id':client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files = files, headers = headers)

# %%
import json  #json형식을 다루는 모듈
parsed = json.loads(response.text)
print(json.dumps(parsed, indent = 4, sort_keys=False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 512,
#             "height": 342
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 322,
#                 "y": 53,
#                 "width": 30,
#                 "height": 30
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 331,
#                     "y": 60
#                 },
#                 "rightEye": {
#                     "x": 344,
#                     "y": 60
#                 },
#                 "nose": {
#                     "x": 337,
#                     "y": 67
#                 },
#                 "leftMouth": {
#                     "x": 333,
#                     "y": 74
#                 },
#                 "rightMouth": {
#                     "x": 343,
#                     "y": 73
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999797
#             },
#             "age": {
#                 "value": "32~36",
#                 "confidence": 0.870835
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.941112
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.990651
#             }
#         },
#         {
#             "roi": {
#                 "x": 268,
#                 "y": 71,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999965
#             },
#             "age": {
#                 "value": "18~22",
#                 "confidence": 0.870391
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.996715
#             },
#             "pose": {
#                 "value": "part_face",
#                 "confidence": 0.777422
#             }
#         },
#         {
#             "roi": {
#                 "x": 173,
#                 "y": 144,
#                 "width": 26,
#                 "height": 26
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.882768
#             },
#             "age": {
#                 "value": "5~9",
#                 "confidence": 0.941211
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.989725
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.895872
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 153,
#                 "width": 24,
#                 "height": 24
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 138,
#                     "y": 159
#                 },
#                 "rightEye": {
#                     "x": 148,
#                     "y": 159
#                 },
#                 "nose": {
#                     "x": 143,
#                     "y": 164
#                 },
#                 "leftMouth": {
#                     "x": 139,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 147,
#                     "y": 168
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.902951
#             },
#             "age": {
#                 "value": "9~13",
#                 "confidence": 0.0996041
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.897915
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.96725
#             }
#         }
#     ]
# }

# %%
import matplotlib.patches as patches

img = mpimg.imread('face2.jpg')

fig, ax = plt.subplots(figsize = (10,10))
ax.imshow(img)

for each in parsed['faces']:
    x,y,w,h = each['roi'].values()
    gender,gen_confi = each['gender'].values()
    emotion,emo_confi = each['emotion'].values()
    age,age_confi = each['age'].values()
    
    rect_face = patches.Rectangle((x,y),w,h,
                                 linewidth = 5,
                                 edgecolor = 'r',
                                 facecolor = 'none')
    ax.add_patch(rect_face)
    annotation = gender + " : " + str(round(gen_confi*100.0)) + '\n' + emotion + " : " + str(round(emo_confi*100.0)) + '\n' + age + " ; " + str(round(age_confi*100.0))
    plt.text(x-30,y-30, annotation, wrap=True, fontsize = 9, color ='black')
    
plt.show()
