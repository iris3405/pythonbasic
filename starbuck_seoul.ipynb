# %%
# 데이터분석

# 스타벅스는 어떤 전략으로 매장입지를 선택할까....(스타벅스는 전부 직영점)

# 2가지 가설...
# 1. 거주 인구가 많은 지역에 스타벅스 매장이 많이 있을 것이다. 
# 2. 직장인이 많은 지역에 스타벅스 매장이 많이 있을 것이다.

# %%
# !pip install selenium

# %%
from selenium import webdriver # 파이썬으로 웹 컨트롤
import pandas as pd            # 데이터 분석 
from bs4 import BeautifulSoup  # 인터넷 가져온 파일 분석

# %%
browser = webdriver.Chrome("C:/Users/kych1/Downloads/chromedriver_win32/chromedriver.exe")

url = "https://www.starbucks.co.kr/store/store_map.do"

browser.get(url)

# %%
find_btn = "#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a"
browser.find_element_by_css_selector(find_btn).click()

# 지역검색 버튼 누르기

# %%
seoul_btn = "#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a"
browser.find_element_by_css_selector(seoul_btn).click()

# 서울 버튼 누르기

# %%
all_btn = "#mCSB_2_container > ul > li:nth-child(1) > a"
browser.find_element_by_css_selector(all_btn).click()

# 전체 버튼 누르기

# %%
html = browser.page_source
print(html)
# Out:
# <html lang="ko"><head>
#
#
#
#
#
#
#
#
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">
# <meta property="og:type" content="website">
# <meta property="og:title" content="Starbucks">
# <meta property="og:url" content="https://www.starbucks.co.kr/">
# <meta property="og:image" content="https://image.istarbucks.co.kr/common/img/kakaotalk.png">
# <meta property="og:description" content="Starbucks">
#
# <title id="titleJoin">Starbucks Coffee Korea</title>
# <link rel="shortcut icon" href="https://image.istarbucks.co.kr/common/img/common/favicon.ico?v=200828" type="image/ico"> <!-- 20200827 파비콘 교체 및 CDN 변수처리 -->
# <link href="/common/css/reset.css" rel="stylesheet">
# <link href="/common/css/style.css?v=200130" rel="stylesheet">
# <link href="/common/css/jquery.bxslider.css" rel="stylesheet">
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <html lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="website" property="og:type"/>
# <meta content="Starbucks" property="og:title"/>
# <meta content="https://www.starbucks.co.kr/" property="og:url"/>
# <meta content="https://image.istarbucks.co.kr/common/img/kakaotalk.png" property="og:image"/>
# <meta content="Starbucks" property="og:description"/>
# <title id="titleJoin">Starbucks Coffee Korea</title>
# <link href="https://image.istarbucks.co.kr/common/img/common/favicon.ico?v=200828" rel="shortcut icon" type="image/ico"/> <!-- 20200827 파비콘 교체 및 CDN 변수처리 -->
# <link href="/common/css/reset.css" rel="stylesheet"/>
# <link href="/common/css/style.css?v=200130" rel="stylesheet"/>
# <link href="/common/css/jquery.bxslider.css" rel="stylesheet"/>
# ...

# %%
# html에서 원하는 데이터만 추출

starbucks_soup_list = soup.select('li.quickResultLstCon')
# print(starbucks_soup_list)
# print(len(starbucks_soup_list))

# %%
print(len(starbucks_soup_list))
# Out:
# 10

# %%
starbucks_soup_list[0]
# Out:
# <li class="quickResultLstCon" data-code="9793" data-hlytag="null" data-index="0" data-lat="37.600585" data-long="127.141922" data-name="구리돌다리" data-storecd="614" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="구리돌다리" data-store="614" data-yn="N">구리돌다리  </strong> <p class="result_details">경기도 구리시 검배로 5, 우진빌딩 (수택동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
starbucks_store = starbucks_soup_list[0]

# %%
print(starbucks_store)
# Out:
# <li class="quickResultLstCon" data-code="9793" data-hlytag="null" data-index="0" data-lat="37.600585" data-long="127.141922" data-name="구리돌다리" data-storecd="614" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="구리돌다리" data-store="614" data-yn="N">구리돌다리  </strong> <p class="result_details">경기도 구리시 검배로 5, 우진빌딩 (수택동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
# 태그로 선택 
name = starbucks_store.select('strong')
print(name)
# Out:
# [<strong data-my_siren_order_store_yn="N" data-name="구리돌다리" data-store="614" data-yn="N">구리돌다리  </strong>]

# %%
name = starbucks_store.select('strong')[0].text.strip()
lat = starbucks_store['data-lat']     # 위도
lng = starbucks_store['data-long']      # 경도
#주소
address = str(starbucks_store.select('p')[0]).split('<br/>')[0].split('>')[1]

#전화번호
tel = str(starbucks_store.select('p')[0]).split('<br/>')[1].split('<')[0]

#매장형태
store_type = starbucks_store.select('i')[0]['class'][0][4:]


print(name)
print(lat)
print(lng)
print(address)
print(tel)
print(store_type)
# Out:
# 구리돌다리
# 37.600585
# 127.141922
# 경기도 구리시 검배로 5, 우진빌딩 (수택동)
# 1522-3232
# general

# %%
starbucks_list = []

for item in starbucks_soup_list:
    name = item.select('strong')[0].text.strip()
    lat = item['data-lat'] # 위도 
    lng = item['data-long'] # 경도
    address = str(item.select('p')[0]).split('<br/>')[0].split('>')[1]
    tel = str(item.select('p')[0]).split('<br/>')[1].split('<')[0]
    store_type = item.select('i')[0]['class'][0][4:]
    
    starbucks_list.append([name, lat, lng, store_type, address, tel])
    
print(starbucks_list)
# Out:
# [['구리돌다리', '37.600585', '127.141922', 'general', '경기도 구리시 검배로 5, 우진빌딩 (수택동)', '1522-3232'], ['구리인창', '37.60688', '127.13896', 'general', '경기도 구리시 건원대로 67, 1층 (인창동)', '1522-3232'], ['도농역', '37.611129', '127.164199', 'general', '경기도 남양주시 미금로 239 1층 101호~106호', '1522-3232'], ['다산진건', '37.624813', '127.152582', 'general', '경기도 남양주시 다산중앙로 123번길 22-26 123호~128호 ', '1522-3232'], ['다산지금', '37.6008111', '127.175355', 'general', '경기도 남양주시 다산지금로139 101~106호', '1522-3232'], ['중랑구청', '37.60538908', '127.0957558', 'general', '서울특별시 중랑구 신내로 72', '1522-3232'], ['상봉', '37.597842', '127.092509', 'general', '서울특별시 중랑구 상봉로 131 (상봉동, 상봉 듀오트리스 주상복합)', '1522-3232'], ['구리갈매역', '37.633967', '127.115944', 'general', '경기도 구리시 경춘북로252 A101 ', '1522-3232'], ['상봉역', '37.59689', '127.08647', 'general', '서울특별시 중랑구 망우로 307 (상봉동)', '1522-3232'], ['사가정역', '37.579594', '127.087966', 'general', '서울특별시 중랑구 면목로 310', '1522-3232']]

# %%
# 데이터프레임으로 변환.

columns = ['매장명','위도','경도','매장타입','주소','전화번호']
seoul_starbucks_df=pd.DataFrame(starbucks_list,columns = columns)

# %%
seoul_starbucks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   매장명     10 non-null     object
#  1   위도      10 non-null     object
#  2   경도      10 non-null     object
#  3   매장타입    10 non-null     object
#  4   주소      10 non-null     object
#  5   전화번호    10 non-null     object
# dtypes: object(6)
# memory usage: 608.0+ bytes

# %%
seoul_starbucks_df
# Out:
#      매장명           위도           경도     매장타입  \
# 0  구리돌다리    37.600585   127.141922  general
# 1   구리인창     37.60688    127.13896  general
# 2    도농역    37.611129   127.164199  general
# 3   다산진건    37.624813   127.152582  general
# 4   다산지금   37.6008111   127.175355  general
# 5   중랑구청  37.60538908  127.0957558  general
# 6     상봉    37.597842   127.092509  general
# 7  구리갈매역    37.633967   127.115944  general
# 8    상봉역     37.59689    127.08647  general
# 9   사가정역    37.579594   127.087966  general
#
#                                        주소       전화번호
# 0               경기도 구리시 검배로 5, 우진빌딩 (수택동)  1522-3232
# 1               경기도 구리시 건원대로 67, 1층 (인창동)  1522-3232
# 2           경기도 남양주시 미금로 239 1층 101호~106호  1522-3232
# 3   경기도 남양주시 다산중앙로 123번길 22-26 123호~128호   1522-3232
# 4              경기도 남양주시 다산지금로139 101~106호  1522-3232
# 5                        서울특별시 중랑구 신내로 72  1522-3232
# 6  서울특별시 중랑구 상봉로 131 (상봉동, 상봉 듀오트리스 주상복합)  1522-3232
# ...

# %%
seoul_starbucks_df.to_excel('seoul_starbucks_list_ByAustin.xlsx', index=False)

# %%
seoul_starbucks_df.drop_duplicates(['매장명'])
# Out:
#      매장명           위도           경도     매장타입  \
# 0  구리돌다리    37.600585   127.141922  general
# 1   구리인창     37.60688    127.13896  general
# 2    도농역    37.611129   127.164199  general
# 3   다산진건    37.624813   127.152582  general
# 4   다산지금   37.6008111   127.175355  general
# 5   중랑구청  37.60538908  127.0957558  general
# 6     상봉    37.597842   127.092509  general
# 7  구리갈매역    37.633967   127.115944  general
# 8    상봉역     37.59689    127.08647  general
# 9   사가정역    37.579594   127.087966  general
#
#                                        주소       전화번호
# 0               경기도 구리시 검배로 5, 우진빌딩 (수택동)  1522-3232
# 1               경기도 구리시 건원대로 67, 1층 (인창동)  1522-3232
# 2           경기도 남양주시 미금로 239 1층 101호~106호  1522-3232
# 3   경기도 남양주시 다산중앙로 123번길 22-26 123호~128호   1522-3232
# 4              경기도 남양주시 다산지금로139 101~106호  1522-3232
# 5                        서울특별시 중랑구 신내로 72  1522-3232
# 6  서울특별시 중랑구 상봉로 131 (상봉동, 상봉 듀오트리스 주상복합)  1522-3232
# ...

# %%
seoul_starbucks_df.drop_duplicates(['매장명'])
# Out:
#      매장명           위도           경도     매장타입  \
# 0  구리돌다리    37.600585   127.141922  general
# 1   구리인창     37.60688    127.13896  general
# 2    도농역    37.611129   127.164199  general
# 3   다산진건    37.624813   127.152582  general
# 4   다산지금   37.6008111   127.175355  general
# 5   중랑구청  37.60538908  127.0957558  general
# 6     상봉    37.597842   127.092509  general
# 7  구리갈매역    37.633967   127.115944  general
# 8    상봉역     37.59689    127.08647  general
# 9   사가정역    37.579594   127.087966  general
#
#                                        주소       전화번호
# 0               경기도 구리시 검배로 5, 우진빌딩 (수택동)  1522-3232
# 1               경기도 구리시 건원대로 67, 1층 (인창동)  1522-3232
# 2           경기도 남양주시 미금로 239 1층 101호~106호  1522-3232
# 3   경기도 남양주시 다산중앙로 123번길 22-26 123호~128호   1522-3232
# 4              경기도 남양주시 다산지금로139 101~106호  1522-3232
# 5                        서울특별시 중랑구 신내로 72  1522-3232
# 6  서울특별시 중랑구 상봉로 131 (상봉동, 상봉 듀오트리스 주상복합)  1522-3232
# ...

# %%
###############################################
# 데이터 전처리 
###############################################

# %%
# 1. 스타벅스 주소에서 시군구명 추출

sgg_names = []

for address in seoul_starbucks_df['주소']:
    sgg = address.split()[1]
    sgg_names.append(sgg)
    
seoul_starbucks_df['시군구명'] = sgg_names

seoul_starbucks_df.head()
# Out:
#      매장명          위도          경도     매장타입  \
# 0  구리돌다리   37.600585  127.141922  general
# 1   구리인창    37.60688   127.13896  general
# 2    도농역   37.611129  127.164199  general
# 3   다산진건   37.624813  127.152582  general
# 4   다산지금  37.6008111  127.175355  general
#
#                                       주소       전화번호  시군구명
# 0              경기도 구리시 검배로 5, 우진빌딩 (수택동)  1522-3232   구리시
# 1              경기도 구리시 건원대로 67, 1층 (인창동)  1522-3232   구리시
# 2          경기도 남양주시 미금로 239 1층 101호~106호  1522-3232  남양주시
# 3  경기도 남양주시 다산중앙로 123번길 22-26 123호~128호   1522-3232  남양주시
# 4             경기도 남양주시 다산지금로139 101~106호  1522-3232  남양주시

# %%
seoul_starbucks_df.to_excel('seoul_starbucks_list_sgg.xlsx', index=False)

# %%
#####################################################
# 스타벅스 데이터 분석
#####################################################
# 구별로 매장의 갯수 

seoul_starbucks = pd.read_excel('seoul_starbucks_list_sgg.xlsx')

seoul_starbucks.head()
# Out:
#      매장명         위도          경도     매장타입  \
# 0  구리돌다리  37.600585  127.141922  general
# 1   구리인창  37.606880  127.138960  general
# 2    도농역  37.611129  127.164199  general
# 3   다산진건  37.624813  127.152582  general
# 4   다산지금  37.600811  127.175355  general
#
#                                       주소       전화번호  시군구명
# 0              경기도 구리시 검배로 5, 우진빌딩 (수택동)  1522-3232   구리시
# 1              경기도 구리시 건원대로 67, 1층 (인창동)  1522-3232   구리시
# 2          경기도 남양주시 미금로 239 1층 101호~106호  1522-3232  남양주시
# 3  경기도 남양주시 다산중앙로 123번길 22-26 123호~128호   1522-3232  남양주시
# 4             경기도 남양주시 다산지금로139 101~106호  1522-3232  남양주시

# %%
seoul_sgg_pop = pd.read_excel("sgg_pop.xlsx")
seoul_sgg_pop.head()
# Out:
#   시군구명   주민등록인구
# 0  종로구  177,023
# 1   중구  138,102
# 2  용산구  250,844
# 3  성동구  316,113
# 4  광진구  386,292

# %%
seoul_sgg_list = pd.read_excel("seoul_sgg_list.xlsx")
seoul_sgg_list.head()
# Out:
#    시군구코드  시군구명         위도          경도
# 0  11320   도봉구  37.665861  127.031767
# 1  11380   은평구  37.617612  126.922700
# 2  11230  동대문구  37.583801  127.050700
# 3  11590   동작구  37.496504  126.944307
# 4  11545   금천구  37.460097  126.900155

# %%
starbucks_sgg_count = seoul_starbucks.pivot_table(index = "시군구명",
                                                 values="매장명",
                                                 aggfunc="count").rename(columns={'매장명':'스타벅스_매장수'})
starbucks_sgg_count.head()
# Out:
#       스타벅스_매장수
# 시군구명
# 구리시          3
# 남양주시         3
# 중랑구          4

# %%
#################################################
# 데이터 병합
#################################################

seoul_sgg = pd.merge(seoul_sgg_pop,seoul_sgg_list, how='left', on="시군구명")
seoul_sgg.head()
# Out:
#   시군구명   주민등록인구  시군구코드         위도          경도
# 0  종로구  177,023  11110  37.599100  126.986149
# 1   중구  138,102  11140  37.557945  126.994190
# 2  용산구  250,844  11170  37.531101  126.981074
# 3  성동구  316,113  11200  37.550675  127.040962
# 4  광진구  386,292  11215  37.548144  127.085753

# %%
seoul_sgg_biz = pd.read_excel("sgg_biz.xlsx")
seoul_sgg_biz.head()
# Out:
#   시군구명    종사자수   사업체수
# 0  종로구  269106  40871
# 1   중구  423808  66190
# 2  용산구  133446  21178
# 3  성동구  162019  26130
# 4  광진구  123689  24531

# %%
seoul_sgg = pd.merge(seoul_sgg,seoul_sgg_biz, how='left', on="시군구명")
seoul_sgg.head()
# Out:
#   시군구명   주민등록인구  시군구코드         위도          경도    종사자수   사업체수
# 0  종로구  177,023  11110  37.599100  126.986149  269106  40871
# 1   중구  138,102  11140  37.557945  126.994190  423808  66190
# 2  용산구  250,844  11170  37.531101  126.981074  133446  21178
# 3  성동구  316,113  11200  37.550675  127.040962  162019  26130
# 4  광진구  386,292  11215  37.548144  127.085753  123689  24531

# %%
seoul_sgg = pd.merge(seoul_sgg,starbucks_sgg_count, how='left', on="시군구명")
seoul_sgg.head()
# Out:
#   시군구명   주민등록인구  시군구코드         위도          경도    종사자수   사업체수  스타벅스_매장수
# 0  종로구  177,023  11110  37.599100  126.986149  269106  40871       NaN
# 1   중구  138,102  11140  37.557945  126.994190  423808  66190       NaN
# 2  용산구  250,844  11170  37.531101  126.981074  133446  21178       NaN
# 3  성동구  316,113  11200  37.550675  127.040962  162019  26130       NaN
# 4  광진구  386,292  11215  37.548144  127.085753  123689  24531       NaN

# %%
seoul_sgg.to_excel('seoul_sgg_ByAustin.xlsx', index=False)

# %%
# 스타벅스 매장 분포 시각화
# !pip install folium
import folium
import pandas as pd
import json

# %%
starbucks_map = folium.Map(location=[37.57,126.97], tiles='Stamen Terrain', zoom_start=11)
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx,'위도']
    lng = seoul_starbucks.loc[idx,'경도']
    
    folium.CircleMarker(
    location=[lat,lng,],
    fill = True).add_to(starbucks_map)
    
starbucks_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
starbucks_sgg_count = seoul_starbucks.pivot_table(index = "매장타입",
                                                 values="매장명",
                                                 aggfunc="count").rename(columns={'매장명':'스타벅스_매장수'})
starbucks_sgg_count.head()
starbucks_map2 = folium.Map(location=[37.57,126.97], tiles='Stamen Terrain', zoom_start=11)


for idx in seoul_starbucks.index:
    lat = seoul_starbucks.loc[idx,'위도']
    lng = seoul_starbucks.loc[idx,'경도']
    
    store_type = seoul_starbucks.loc[idx,'매장타입']
    
    fillColor = ''
    
    if store_type == 'general':
        fillColor = 'gray'
        size = 1
    elif store_type == 'generalDT':
        fillColor = 'red'
        size = 5
    elif store_type == 'generalWT':
        fillColor = 'orange'
        size = 10
    else :
        fillColor = 'blue'
        size = 3
    
    folium.CircleMarker(
    location=[lat,lng,],
    color = fillColor,
    radius = size).add_to(starbucks_map2)
    
starbucks_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
###############################
# 시군구별 시각화
###############################
seoul_sgg_stat = pd.read_excel('seoul_sgg_stat.xlsx', thousands = ',')
seoul_sgg_stat.head()
seoul_sgg_geo = json.load(open('seoul_sgg.geojson', encoding='utf-8'))
print(seoul_sgg_geo)

def style_function(feature):
    return {
        'opacity':0.7,
        'weight':1,
        'color': 'blue',
        'fillOpacity':0,
        'dashArray': '5,5',
    }


folium.GeoJson(
    seoul_sgg_geo,
style_function=style_function).add_to(starbucks_bubble)


starbucks_bubble
starbucks_bubble = folium.Map(location=[37.57,126.97], tiles='Stamen Terrain', zoom_start=11)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-84-0eadf7519731> in <module>
#       2 # 시군구별 시각화
#       3 ###############################
# ----> 4 seoul_sgg_stat = pd.read_excel('seoul_sgg_stat.xlsx', thousands = ',')
#       5 seoul_sgg_stat.head()
#       6 seoul_sgg_geo = json.load(open('seoul_sgg.geojson', encoding='utf-8'))
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...
